# %% [markdown]
# # School Management System

# %%
print("***Student Management System***")
print()
print("Enter 1 to Add")
print("Enter 2 to Update")
print("Enter 3 to Delete")
print("Enter 4 to View")
print("Enter 5 to Exit")
print("****************************")
print()
choice = input("Enter your Choice: ")
while choice != "5":
    #choice = int(input("Enter your Choice"))
    if choice == "1":
        print("you have selected Add option")
        print()
        print("***Student Management System***")

        print("Enter 1 to Add")
        print("Enter 2 to Update")
        print("Enter 3 to Delete")
        print("Enter 4 to View")
        print("Enter 5 to Exit")
        print("****************************")
        choice = input("Enter your Choice: ")
    elif choice == "2":
        print("you have selected Update option")
        print()
        print("***Student Management System***")

        print("Enter 1 to Add")
        print("Enter 2 to Update")
        print("Enter 3 to Delete")
        print("Enter 4 to View")
        print("Enter 5 to Exit")
        print("****************************")
        choice = input("Enter your Choice: ")
        
    elif choice == "3":
        print("you have selected Delete option")
        print()
        print("***Student Management System***")

        print("Enter 1 to Add")
        print("Enter 2 to Update")
        print("Enter 3 to Delete")
        print("Enter 4 to View")
        print("Enter 5 to Exit")
        print("****************************")
        choice = input("Enter your Choice: ")
    elif choice == "4":
        print("You have selected View option")
        print()
        print("***Student Management System***")

        print("Enter 1 to Add")
        print("Enter 2 to Update")
        print("Enter 3 to Delete")
        print("Enter 4 to View")
        print("Enter 5 to Exit")
        print("****************************")
        choice = input("Enter your Choice: ")
    else:
        print("you have enter invalid query")
        print()
        print("***Student Management System***")

        print("Enter 1 to Add")
        print("Enter 2 to Update")
        print("Enter 3 to Delete")
        print("Enter 4 to View")
        print("Enter 5 to Exit")
        print("****************************")
        choice = input("Enter your Choice: ")
# Out:
# ***Student Management System***
#
# Enter 1 to Add
# Enter 2 to Update
# Enter 3 to Delete
# Enter 4 to View
# Enter 5 to Exit
# ****************************
#
# Enter your Choice: 1
# you have selected Add option
#
# ***Student Management System***
# Enter 1 to Add
# Enter 2 to Update
# Enter 3 to Delete
# Enter 4 to View
# Enter 5 to Exit
# ****************************
# Enter your Choice: 2
# you have selected Update option
#
# ***Student Management System***
# Enter 1 to Add
# Enter 2 to Update
# Enter 3 to Delete
# Enter 4 to View
# Enter 5 to Exit
# ****************************
# Enter your Choice: 3
# you have selected Delete option
#
# ***Student Management System***
# Enter 1 to Add
# Enter 2 to Update
# Enter 3 to Delete
# Enter 4 to View
# Enter 5 to Exit
# ****************************
# Enter your Choice: 4
# You have selected View option
#
# ***Student Management System***
# Enter 1 to Add
# Enter 2 to Update
# Enter 3 to Delete
# Enter 4 to View
# Enter 5 to Exit
# ****************************
# Enter your Choice: g
# you have enter invalid query
#
# ***Student Management System***
# Enter 1 to Add
# Enter 2 to Update
# Enter 3 to Delete
# Enter 4 to View
# Enter 5 to Exit
# ****************************
# Enter your Choice: 5
